# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
loc = 'MARL/results/Jun_12_06_03_34/eval_logs'
reward = np.load(loc+'/reward_difficulty_1.npy')
rewardSTD = np.load(loc+'/rewardSTD_difficulty_1.npy')

plt.figure()
plt.plot(reward)
plt.xlabel("Episode")
plt.ylabel("Average Reward")
# Out:
# Text(0, 0.5, 'Average Reward')

# %%
def smooth(x, timestamps=9):
    n = len(x)
    y = np.zeros(n)
    for i in range(n):
        start = max(0, i - timestamps)
        y[i] = float(x[start:(i + 1)].sum()) / (i - start + 1)
    return y


matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
color_cycle = sns.color_palette()
sns.set_color_codes()

colors = [0, 5, 2, 6, 1, 3]

alpha = 0.3
legend_size = 15
line_size_others = 2
line_size_ours = 2
tick_size = 18
label_size = 18
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 12
#      10 matplotlib.rcParams['pdf.fonttype'] = 42
#      11 matplotlib.rcParams['ps.fonttype'] = 42
# ---> 12 color_cycle = sns.color_palette()
#      13 sns.set_color_codes()
#      15 colors = [0, 5, 2, 6, 1, 3]
#
# NameError: name 'sns' is not defined

# %%
X = np.arange(len(reward))
lower_bound = reward - rewardSTD
upper_bound = reward + rewardSTD

fig, ax0 = plt.subplots(ncols=1, figsize=(6, 4))
ax0.set_title('Easy Mode', size=label_size)

ax0.plot(X, reward, lw=line_size_others, label='MAA2C', linestyle=':',
         color=color_cycle[colors[0]])

ax0.fill_between(X, easy_maa2c_lower_bound[:obs_window], easy_maa2c_upper_bound[:obs_window],
                 facecolor=color_cycle[colors[0]], edgecolor='none', alpha=alpha)

ax0.set_xlim(0, obs_window)
ax0.set_ylim(10, 80)
ax0.tick_params(axis='x', labelsize=tick_size)
ax0.tick_params(axis='y', labelsize=tick_size)
ax0.set_xlabel('Evaluation epochs', fontsize=label_size)
ax0.set_ylabel('Evaluation reward', fontsize=label_size)
ax0.ticklabel_format(axis="x")

ax0.grid()
# set the linewidth of each legend object
for legobj in leg0.legendHandles:
    legobj.set_linewidth(2.0)
